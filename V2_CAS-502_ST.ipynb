# %%
import streamlit as st
import pandas as pd
import pickle as pkl
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler 
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

st.title("Hospital Length of Stay Predictor")
# Out:
# 2025-02-25 19:14:17.539 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:14:18.079
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-02-25 19:14:18.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Section 1 - Model based on Hospital-LOS

st.header("Base Model (Hostpital-LOS.csv)")

# Load Base Data

data_base = pd.read_csv('Hospital-LOS.csv')

print(type(data_base))
# Out:
# 2025-02-25 19:30:11.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:30:11.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data_base.columns)
# Out:
# Index(['Available Extra Rooms in Hospital', 'Department', 'Ward_Facility_Code',
#        'doctor_name', 'staff_available', 'patientid', 'Age', 'gender',
#        'Type of Admission', 'Severity of Illness', 'health_conditions',
#        'Visitors with Patient', 'Insurance', 'Stay (in days)'],
#       dtype='object')

# %%
print(type(data_base))
print(type(X_base))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions on the test set
y_pred_base = model.predict(X_test_base)

# Calculate metrics
mae = mean_absolute_error(y_test_base, y_pred_base)
mse = mean_squared_error(y_test_base, y_pred_base)
r2 = r2_score(y_test_base, y_pred_base)

print("MAE:", mae)
print("MSE:", mse)
print("R^2 Score:", r2)
# Out:
# MAE: 1.2405153187399511
# MSE: 3.4202028539614244
# R^2 Score: 0.9447086063740399

# %%
# Define target and features
X_base = data_base.drop(columns=['Stay (in days)', 'patientid'])
y_base = data_base['Stay (in days)']

# Identify categorical and numeric columns
categorical_cols = X_base.select_dtypes(include=['object']).columns
numeric_cols = X_base.select_dtypes(include=['number']).columns

# Create preprocessor
preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols),
    ('num', StandardScaler(), numeric_cols)
])

# Split data
X_train_base, X_test_base, y_train_base, y_test_base = train_test_split(X_base, y_base, test_size=0.2, random_state=42)

# Build pipeline
model = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42))
])

# Train model
model.fit(X_train_base, y_train_base)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Department', 'Ward_Facility_Code', 'doctor_name', 'Age', 'gender',
#        'Type of Admission', 'Severity of Illness', 'health_conditions',
#        'Insurance'],
#       dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['Available Extra Rooms in Hospital', 'staff_available',
#        'Visitors with Patient'],
#       dtype='object'))])),
#                 ('regressor', RandomForestRegressor(random_state=42))])

# %%
# Evaluate model
y_pred_base = model.predict(X_test_base)
st.write("**Evaluation Metrics:**")
st.write("MAE:", mean_absolute_error(y_test_base, y_pred_base))
st.write("MSE:", mean_squared_error(y_test_base, y_pred_base))
st.write("R² Score:", r2_score(y_test_base, y_pred_base))

st.subheader("Predict LOS for a New Patient (Base Model)")

# Define interactive widgets based on base data columns.
available_rooms = st.number_input("Available Extra Rooms in Hospital", min_value=0, value=3)
department = st.selectbox("Department", options=data_base['Department'].unique())
ward_code = st.selectbox("Ward Facility Code", options=data_base['Ward_Facility_Code'].unique())
doctor_name = st.selectbox("Doctor Name", options=data_base['doctor_name'].unique())
staff_available = st.number_input("Staff Available", min_value=0, value=15)
age_group = st.selectbox("Age Group", options=data_base['Age'].unique())
gender = st.selectbox("Gender", options=data_base['gender'].unique())
admission_type = st.selectbox("Type of Admission", options=data_base['Type of Admission'].unique())
severity = st.selectbox("Severity of Illness", options=data_base['Severity of Illness'].unique())
health_conditions = st.selectbox("Health Conditions", options=data_base['health_conditions'].unique())
visitors = st.number_input("Visitors with Patient", min_value=0, value=2)
insurance = st.selectbox("Insurance", options=data_base['Insurance'].unique())

new_patient_base = {
    'Available Extra Rooms in Hospital': available_rooms,
    'Department': department,
    'Ward_Facility_Code': ward_code,
    'doctor_name': doctor_name,
    'staff_available': staff_available,
    'Age': age_group,
    'gender': gender,
    'Type of Admission': admission_type,
    'Severity of Illness': severity,
    'health_conditions': health_conditions,
    'Visitors with Patient': visitors,
    'Insurance': insurance
}

if st.button("Predict LOS (Base Model)"):
    new_patient_df = pd.DataFrame([new_patient_base])
    predicted_stay = model.predict(new_patient_df)
    st.success(f"Predicted Length of Stay: {predicted_stay[0]:.2f} days")
# Out:
# 2025-02-25 19:55:40.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.376 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.383 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.439 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.479 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:55:40.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Section 2: Updated Model with Co-morbidities
#############################
st.header("Updated Model with Co-morbidities (Hospital_LOS_with_Comorbidities.csv)")

# Load updated dataset
data_updated = pd.read_csv('Hospital_LOS_with_Comorbidities.csv')

# Define target and features
X_updated = data_updated.drop(columns=['Stay (in days)', 'patientid'])
y_updated = data_updated['Stay (in days)']

# Identify columns for updated data
categorical_cols_updated = X_updated.select_dtypes(include=['object']).columns
numeric_cols_updated = X_updated.select_dtypes(include=['number']).columns

# Updated preprocessor
preprocessor_updated = ColumnTransformer([
    ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols_updated),
    ('num', StandardScaler(), numeric_cols_updated)
])

# Split data
X_train_updated, X_test_updated, y_train_updated, y_test_updated = train_test_split(X_updated, y_updated, test_size=0.2, random_state=42)

# Build updated model pipeline
updated_model = Pipeline([
    ('preprocessor', preprocessor_updated),
    ('regressor', RandomForestRegressor(random_state=42))
])

# Train updated model
updated_model.fit(X_train_updated, y_train_updated)
# Out:
# 2025-02-25 19:56:06.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:56:06.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Department', 'Ward_Facility_Code', 'doctor_name', 'Age', 'gender',
#        'Type of Admission', 'Severity of Illness', 'health_conditions',
#        'Insurance'],
#       dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['Available Extra Rooms in Hospital', 'staff_available',
#        'Visitors with Patient', 'Septicemia', 'CHF', 'Pneumonia',
#        'COPD_Bronchiectasis', 'Cardiac_Dysrhythmias',
#        'Acute_Cerebrovascular_Disease', 'Acute_Renal_Failure',
#        'Skin_Infections', 'UTI'],
#       dtype='object'))])),
#                 ('regressor', RandomForestRegressor(random_state=42))])

# %%
# Evaluate updated model
y_pred_updated = updated_model.predict(X_test_updated)
st.write("**Updated Model Evaluation Metrics:**")
st.write("MAE:", mean_absolute_error(y_test_updated, y_pred_updated))
st.write("MSE:", mean_squared_error(y_test_updated, y_pred_updated))
st.write("R² Score:", r2_score(y_test_updated, y_pred_updated))

st.subheader("Predict LOS for a New Patient (Updated Model)")

# Define widgets for updated model input.
available_rooms_upd = st.number_input("Available Extra Rooms in Hospital (Updated)", min_value=0, value=3, key="rooms_upd")
department_upd = st.selectbox("Department (Updated)", options=data_updated['Department'].unique(), key="dept_upd")
ward_code_upd = st.selectbox("Ward Facility Code (Updated)", options=data_updated['Ward_Facility_Code'].unique(), key="ward_upd")
doctor_name_upd = st.selectbox("Doctor Name (Updated)", options=data_updated['doctor_name'].unique(), key="doc_upd")
staff_available_upd = st.number_input("Staff Available (Updated)", min_value=0, value=15, key="staff_upd")
age_group_upd = st.selectbox("Age Group (Updated)", options=data_updated['Age'].unique(), key="age_upd")
gender_upd = st.selectbox("Gender (Updated)", options=data_updated['gender'].unique(), key="gender_upd")
admission_type_upd = st.selectbox("Type of Admission (Updated)", options=data_updated['Type of Admission'].unique(), key="adm_upd")
severity_upd = st.selectbox("Severity of Illness (Updated)", options=data_updated['Severity of Illness'].unique(), key="sev_upd")
health_conditions_upd = st.selectbox("Health Conditions (Updated)", options=data_updated['health_conditions'].unique(), key="hc_upd")
visitors_upd = st.number_input("Visitors with Patient (Updated)", min_value=0, value=2, key="visitors_upd")
insurance_upd = st.selectbox("Insurance (Updated)", options=data_updated['Insurance'].unique(), key="ins_upd")
# Additional co-morbidity fields
septicemia = st.number_input("Septicemia", min_value=0, value=0, key="septicemia")
chf = st.number_input("CHF", min_value=0, value=0, key="chf")
pneumonia = st.number_input("Pneumonia", min_value=0, value=0, key="pneumonia")
copd = st.number_input("COPD_Bronchiectasis", min_value=0, value=0, key="copd")
cardiac = st.number_input("Cardiac_Dysrhythmias", min_value=0, value=0, key="cardiac")
cerebrovascular = st.number_input("Acute_Cerebrovascular_Disease", min_value=0, value=0, key="cerebrovascular")
renal_failure = st.number_input("Acute_Renal_Failure", min_value=0, value=0, key="renal_failure")
skin_infections = st.number_input("Skin_Infections", min_value=0, value=0, key="skin_infections")
uti = st.number_input("UTI", min_value=0, value=0, key="uti")

new_patient_updated = {
    'Available Extra Rooms in Hospital': available_rooms_upd,
    'Department': department_upd,
    'Ward_Facility_Code': ward_code_upd,
    'doctor_name': doctor_name_upd,
    'staff_available': staff_available_upd,
    'Age': age_group_upd,
    'gender': gender_upd,
    'Type of Admission': admission_type_upd,
    'Severity of Illness': severity_upd,
    'health_conditions': health_conditions_upd,
    'Visitors with Patient': visitors_upd,
    'Insurance': insurance_upd,
    'Septicemia': septicemia,
    'CHF': chf,
    'Pneumonia': pneumonia,
    'COPD_Bronchiectasis': copd,
    'Cardiac_Dysrhythmias': cardiac,
    'Acute_Cerebrovascular_Disease': cerebrovascular,
    'Acute_Renal_Failure': renal_failure,
    'Skin_Infections': skin_infections,
    'UTI': uti
}

if st.button("Predict LOS (Updated Model)"):
    new_patient_updated_df = pd.DataFrame([new_patient_updated])
    predicted_stay_updated = updated_model.predict(new_patient_updated_df)
    st.success(f"Predicted Length of Stay: {predicted_stay_updated[0]:.2f} days")
# Out:
# 2025-02-25 19:57:37.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.580 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.668 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.785 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-25 19:57:37.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !streamlit run streamlit_app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8502
#   Network URL: http://192.168.0.235:8502
